# %%
import re
import string
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import WordPunctTokenizer
from nltk.stem.snowball import SnowballStemmer

from sklearn.base import TransformerMixin

# %% [markdown]
# Load datasets:

# %%
train_dataset = pd.read_csv("../aux_data/mapped_dataset.csv")
print(len(train_dataset))
train_dataset.head()
# Out:
# 9372
#                                                 text        date  \
# 0  Hello, Does it matter iff I use Visa or Master...    7-6-2022
# 1  Good afternoon, I just got refunded for my pur...  16-11-2022
# 2        Hello, I got billed ann extra pound! Thanks   4-12-2022
# 3  Hi, How long does it take for a transfer to sh...  23-11-2022
# 4  hi, When can I use money sent to my accountt? ...   17-4-2022
#
#                     category language     class
# 0         visa_or_mastercard       en      card
# 1     reverted_card_payment?       en      card
# 2  extra_charge_on_statement       en    others
# 3            transfer_timing       en  transfer
# 4            transfer_timing       en  transfer

# %%
train_dataset = train_dataset.dropna()
print(len(train_dataset))
# Out:
# 9338

# %%
test_dataset = pd.read_csv("../data/test_dataset.csv")
test_dataset.head()
# Out:
#                                                 text
# 0                           How do I locate my card?
# 1              Why won't my card show up on the app?
# 2                I need to know your exchange rates.
# 3  I purchased something in a foreign currency bu...
# 4  My statement has a dollar I have been charged ...

# %% [markdown]
# # 1. Filtering

# %%
train_dataset = train_dataset[(train_dataset["language"] == "en")].drop(["category"], axis=1)
print(len(train_dataset))
train_dataset
# Out:
# 9038
#                                                    text        date language  \
# 0     Hello, Does it matter iff I use Visa or Master...    7-6-2022       en
# 1     Good afternoon, I just got refunded for my pur...  16-11-2022       en
# 2           Hello, I got billed ann extra pound! Thanks   4-12-2022       en
# 3     Hi, How long does it take for a transfer to sh...  23-11-2022       en
# 4     hi, When can I use money sent to my accountt? ...   17-4-2022       en
# ...                                                 ...         ...      ...
# 9367  good afternoon, I think someone may be using m...   22-6-2022       en
# 9368  good morning, Help, I need to top up my accoun...    7-4-2022       en
# 9369  hi, I made an international purchasee, but the...   7-12-2022       en
# 9370     hi, Why is my card not working anymore? Thanks   1-11-2022       en
# 9371  Hello, How many different cards can I havee fo...   24-4-2022       en
#
#          class
# 0         card
# 1         card
# 2       others
# 3     transfer
# 4     transfer
# ...        ...
# 9367      card
# 9368      cash
# 9369      card
# 9370      card
# 9371      card
#
# [9038 rows x 4 columns]

# %% [markdown]
# # 2. Text Processing

# %% [markdown]
# ## Text preprocessing

# %%
# Custom transformer to implement sentence cleaning and normalization
class TextCleanerTransformer(TransformerMixin):
    def __init__(self, tokenizer, stopwords, stemmer, regex_list, lower=True):
        self.regex_list = regex_list
        self.tokenizer = tokenizer
        self.stopwords = stopwords
        self.lower = lower
        self.stemmer = stemmer
        
    def transform(self, df, *_):
        X = list(map(self._clean_text, df))
        return X
    
    def _clean_text(self, text):
    
        # lowercase
        if self.lower:
            text = text.lower()

        # Remove punctuation
        text = re.sub(r'[^\w\s]', '', text)

        # Replace given regexes
        for regex in regex_list:
            text = re.sub(regex, "", text) 

        # Split sentence into list of words
        words = tokenizer.tokenize(text)

        words_ = []
        for word in words:        
            pattern = re.findall(r"(.)\1{2,}", word)

            # Remove more than 3 equal characters
            if pattern != []:
                for i in pattern:
                    word = re.sub(i+"{2,}", i+i, word)

            # Remove stopwords
            if word not in stopwords:
                # stemming
                words_.append(stemmer.stem(word))

        # Join list elements into string
        text = " ".join(words_)
                
        return text
    
    def fit(self, *_):
        return self

# %%
tokenizer = WordPunctTokenizer()
stopwords = stopwords.words('english')
stemmer = SnowballStemmer(language='english')

regex_list = ["hello", "hi", "good morning", "good afternoon", "good evening", "thanks", "best regards", "kind regards"]

def process_text(df, tokenizer, stopwords, stemmer, regex_list):
    cleaner = TextCleanerTransformer(tokenizer, regex_list, stopwords, stemmer)
    
    df_new = df.copy()
    df_new['clean_text'] = cleaner.transform(df_new.text)
    return df_new

# %%
clean_train_dataset = process_text(train_dataset, tokenizer, stopwords, stemmer, regex_list)
clean_train_dataset.head()
# Out:
#                                                 text        date language  \
# 0  Hello, Does it matter iff I use Visa or Master...    7-6-2022       en
# 1  Good afternoon, I just got refunded for my pur...  16-11-2022       en
# 2        Hello, I got billed ann extra pound! Thanks   4-12-2022       en
# 3  Hi, How long does it take for a transfer to sh...  23-11-2022       en
# 4  hi, When can I use money sent to my accountt? ...   17-4-2022       en
#
#       class                       clean_text
# 0      card   matter iff use visa mastercard
# 1      card  got refund purchas two week ago
# 2    others         got bill ann extra pound
# 3  transfer  long take transfer show account
# 4  transfer          use money sent accountt

# %%
clean_test_dataset = process_text(test_dataset, tokenizer, stopwords, stemmer, regex_list)
clean_test_dataset.head()
# Out:
#                                                 text  \
# 0                           How do I locate my card?
# 1              Why won't my card show up on the app?
# 2                I need to know your exchange rates.
# 3  I purchased something in a foreign currency bu...
# 4  My statement has a dollar I have been charged ...
#
#                                          clean_text
# 0                                        locat card
# 1                                wont card show app
# 2                            need know exchang rate
# 3  purchas sometng foreign currenc rate appli wrong
# 4                       statement dollar charg show

# %% [markdown]
# ## Adding extra features

# %%
characters_count = lambda text: len(text)
words_count = lambda text: len(tokenizer.tokenize(text))
unique_words_count = lambda text: len(set(tokenizer.tokenize(text)))

# add characters columns
clean_train_dataset["characters_count"] = list(map(characters_count, clean_train_dataset["text"]))
clean_train_dataset["clean_characters_count"] = list(map(characters_count, clean_train_dataset["clean_text"]))

# add word columns
clean_train_dataset["words_count"] = list(map(words_count, clean_train_dataset["text"]))
clean_train_dataset["clean_words_count"] = list(map(words_count, clean_train_dataset["clean_text"]))

clean_train_dataset["unique_words_count"] = list(map(unique_words_count, clean_train_dataset["text"]))
clean_train_dataset["clean_unique_words_count"] = list(map(unique_words_count, clean_train_dataset["clean_text"]))

clean_train_dataset
# Out:
#                                                    text        date language  \
# 0     Hello, Does it matter iff I use Visa or Master...    7-6-2022       en
# 1     Good afternoon, I just got refunded for my pur...  16-11-2022       en
# 2           Hello, I got billed ann extra pound! Thanks   4-12-2022       en
# 3     Hi, How long does it take for a transfer to sh...  23-11-2022       en
# 4     hi, When can I use money sent to my accountt? ...   17-4-2022       en
# ...                                                 ...         ...      ...
# 9367  good afternoon, I think someone may be using m...   22-6-2022       en
# 9368  good morning, Help, I need to top up my accoun...    7-4-2022       en
# 9369  hi, I made an international purchasee, but the...   7-12-2022       en
# 9370     hi, Why is my card not working anymore? Thanks   1-11-2022       en
# 9371  Hello, How many different cards can I havee fo...   24-4-2022       en
#
#          class                               clean_text  characters_count  \
# 0         card           matter iff use visa mastercard                58
# 1         card          got refund purchas two week ago                83
# 2       others                 got bill ann extra pound                43
# 3     transfer          long take transfer show account                73
# 4     transfer                  use money sent accountt                58
# ...        ...                                      ...               ...
# 9367      card                  tnk someon may use card                66
# 9368      cash         help need top account send check                86
# 9369      card  made intern purchase exchang rate wrong                77
# 9370      card                         card work anymor                46
# 9371      card            mani differ card have account                72
#
#       clean_characters_count  words_count  clean_words_count  \
# 0                         30           13                  5
# 1                         31           16                  6
# 2                         24           10                  5
# 3                         31           18                  5
# 4                         23           14                  4
# ...                      ...          ...                ...
# 9367                      23           14                  5
# 9368                      32           22                  6
# 9369                      39           15                  6
# 9370                      16           11                  3
# 9371                      29           15                  5
#
#       unique_words_count  clean_unique_words_count
# 0                     13                         5
# 1                     16                         6
# 2                     10                         5
# 3                     18                         5
# 4                     14                         4
# ...                  ...                       ...
# 9367                  14                         5
# 9368                  20                         6
# 9369                  14                         6
# 9370                  11                         3
# 9371                  15                         5
#
# [9038 rows x 11 columns]

# %%
def mean(df_train, columns_list):
    df = pd.DataFrame()

    df["class"] = df_train["class"].unique()
    df["rows"] = [count for count in df_train.groupby(['class'])["text"].count()]
    
    for i in columns_list:
        df[i] = [valeu for valeu in df_train.groupby(['class'])[i].sum()]
        df[i+"_mean"] = [int(df[i][l]/df["rows"][l]) for l in range(len(df))]
        
        df = df.drop(i, axis=1)
    
    return df

# %%
# new feature mean analysis: check if is better to keep the values based on text or clean_text column
columns_list = ["characters_count",  "words_count", "unique_words_count", "clean_characters_count",
                "clean_words_count", "clean_unique_words_count"]

mean = mean(clean_train_dataset, columns_list)
mean
# Out:
#       class  rows  characters_count_mean  words_count_mean  \
# 0      card  2966                     76                16
# 1    others  1164                     94                20
# 2  transfer  2982                     79                17
# 3      cash   625                     68                15
# 4  security  1301                     97                20
#
#    unique_words_count_mean  clean_characters_count_mean  \
# 0                       16                           29
# 1                       19                           40
# 2                       16                           31
# 3                       14                           25
# 4                       19                           42
#
#    clean_words_count_mean  clean_unique_words_count_mean
# 0                       5                              5
# 1                       7                              6
# 2                       5                              5
# 3                       4                              4
# 4                       7                              6

# %%
# drop columns based on clean_text column
clean_train_dataset = clean_train_dataset.drop(["clean_words_count", "clean_characters_count", "clean_unique_words_count"], axis=1)
clean_train_dataset
# Out:
#                                                    text        date language  \
# 0     Hello, Does it matter iff I use Visa or Master...    7-6-2022       en
# 1     Good afternoon, I just got refunded for my pur...  16-11-2022       en
# 2           Hello, I got billed ann extra pound! Thanks   4-12-2022       en
# 3     Hi, How long does it take for a transfer to sh...  23-11-2022       en
# 4     hi, When can I use money sent to my accountt? ...   17-4-2022       en
# ...                                                 ...         ...      ...
# 9367  good afternoon, I think someone may be using m...   22-6-2022       en
# 9368  good morning, Help, I need to top up my accoun...    7-4-2022       en
# 9369  hi, I made an international purchasee, but the...   7-12-2022       en
# 9370     hi, Why is my card not working anymore? Thanks   1-11-2022       en
# 9371  Hello, How many different cards can I havee fo...   24-4-2022       en
#
#          class                               clean_text  characters_count  \
# 0         card           matter iff use visa mastercard                58
# 1         card          got refund purchas two week ago                83
# 2       others                 got bill ann extra pound                43
# 3     transfer          long take transfer show account                73
# 4     transfer                  use money sent accountt                58
# ...        ...                                      ...               ...
# 9367      card                  tnk someon may use card                66
# 9368      cash         help need top account send check                86
# 9369      card  made intern purchase exchang rate wrong                77
# 9370      card                         card work anymor                46
# 9371      card            mani differ card have account                72
#
#       words_count  unique_words_count
# 0              13                  13
# 1              16                  16
# 2              10                  10
# 3              18                  18
# 4              14                  14
# ...           ...                 ...
# 9367           14                  14
# 9368           22                  20
# 9369           15                  14
# 9370           11                  11
# 9371           15                  15
#
# [9038 rows x 8 columns]

# %%
clean_train_dataset.to_csv("../aux_data/train_dataset_preprocessed.csv", index=False)

# %%
# add characters columns
clean_test_dataset["characters_count"] = list(map(characters_count, clean_test_dataset["text"]))

# add word columns
clean_test_dataset["words_count"] = list(map(words_count, clean_test_dataset["text"]))
clean_test_dataset["unique_words_count"] = list(map(unique_words_count, clean_test_dataset["text"]))

# %%
clean_test_dataset.to_csv("../aux_data/test_dataset_preprocessed.csv", index=False)
clean_test_dataset
# Out:
#                                                    text  \
# 0                              How do I locate my card?
# 1                 Why won't my card show up on the app?
# 2                   I need to know your exchange rates.
# 3     I purchased something in a foreign currency bu...
# 4     My statement has a dollar I have been charged ...
# ...                                                 ...
# 1037                      Can I use my card in Austria?
# 1038         Do you have to be in the UK to get a card?
# 1039                 Can I use this all over the world?
# 1040      Can I get a card even though I live in the US
# 1041      Do you provide cards to people not in the UK?
#
#                                             clean_text  characters_count  \
# 0                                           locat card                24
# 1                                   wont card show app                37
# 2                               need know exchang rate                35
# 3     purchas sometng foreign currenc rate appli wrong                73
# 4                          statement dollar charg show                63
# ...                                                ...               ...
# 1037                                  use card austria                29
# 1038                                       uk get card                42
# 1039                                      use ts world                34
# 1040                      get card even though live us                45
# 1041                              provid card peopl uk                45
#
#       words_count  unique_words_count
# 0               7                   7
# 1              12                  12
# 2               8                   8
# 3              13                  13
# 4              14                  14
# ...           ...                 ...
# 1037            8                   8
# 1038           13                  12
# 1039            9                   9
# 1040           12                  11
# 1041           11                  11
#
# [1042 rows x 5 columns]
